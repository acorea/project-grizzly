# %%
import pandas as pd
from pandas.core.frame import DataFrame
import matplotlib.pyplot as plt

# %%
# Elon database csv
elon_df: DataFrame = pd.read_csv('elon_twitter_database/elon_sentsubj.csv', parse_dates=['created_at'], date_parser=pd.to_datetime)
elon_df.head()
# Out:
#                     id                                              tweet  \
# 0  1409968558877003776  @torybruno @Dynetics Should I bring a few spar...
# 1  1409968188620673030                          @torybruno @Dynetics Sure
# 2  1409964008682098688  @PassionFlix @ToscaMusk I liked your movie “Ho...
# 3  1409963681807544320  @nextspaceflight There is the internal goal if...
# 4  1409960205920649220  @torybruno @Dynetics When do the engines arriv...
#
#            created_at                                       noun_phrases  \
# 0 2021-06-29 13:14:35   ['@ torybruno @', 'dynetics', 'spare engines …']
# 1 2021-06-29 13:13:06                 ['@ torybruno @', 'dynetics sure']
# 2 2021-06-29 12:56:30  ['passionflix', 'toscamusk', 'movie “', 'holly...
# 3 2021-06-29 12:55:12  ['@ nextspaceflight', 'internal goal', 'obviou...
# 4 2021-06-29 12:41:23                      ['@ torybruno @', 'dynetics']
#
#    polarity  subjectivity
# 0 -0.256250      0.393750
# 1  0.500000      0.888889
# 2  0.750000      0.800000
# 3  0.095238      0.278571
# 4  0.000000      0.000000

# %%
# Sort Dataframe by create_at date
elon_df = elon_df.sort_values(by='created_at')

# %%
# Function to change subject string into a list of strings
def is_subject(subject_field, subject_set):
    subjects = set([i.lower().replace("'", '') for i in subject_field.strip('[]').split(', ')])
    check_subject = list(subject_set & subjects) != []
    if check_subject:
        return 1
    else:
        return 0

# %%
# For FUnction: Noun phrases I want to find in database
tesla_fields = set(['tesla', 'autopilot'])
btc_fields = set(['btc', 'bitcoin'])
eth_fields = set(['ethereum', 'eth'])
doge_fields = set(['dogecoin', 'doge', 'egod'])
crypto_fields = {*btc_fields, *eth_fields, *doge_fields, *['crypto', 'moon', 'currency']}

# %%
# For Function: Creating column to store values from the function.
elon_df['is_tesla'] = elon_df['noun_phrases'].apply(func=is_subject, subject_set=tesla_fields)
elon_df['is_doge'] = elon_df['noun_phrases'].apply(func=is_subject, subject_set=doge_fields)
elon_df['is_btc'] = elon_df['noun_phrases'].apply(func=is_subject, subject_set=btc_fields)
elon_df['is_crypto'] = elon_df['noun_phrases'].apply(func=is_subject, subject_set=crypto_fields)

# %%
# DataFrames for each variable I want to plot
tesla_tweets: DataFrame = elon_df.loc[elon_df['is_tesla']==True]
dodge_tweets: DataFrame = elon_df.loc[elon_df['is_doge']==True]
btc_tweets: DataFrame = elon_df.loc[elon_df['is_btc']==True]
crypto_tweets: DataFrame = elon_df.loc[elon_df['is_crypto']==True]

# %%
# Setting up bitcoin dataframe
bitcoin = R'bitcoin_database\Cleaned\BTCUSDT.csv'
bitcoin_df = pd.read_csv(bitcoin)
for col in ['Open Time', 'Close Time']:
    bitcoin_df[col] = pd.to_datetime(bitcoin_df[col], unit='ms')
bitcoin_df = bitcoin_df.drop(columns=['Close', 'Close Time'])

# Setting up dogecoin dataframe
dogecoin = R'dogecoin_database\Cleaned\DOGEUSDT.csv'
dogecoin_df = pd.read_csv(dogecoin)
for col in ['Open Time', 'Close Time']:
    dogecoin_df[col] = pd.to_datetime(dogecoin_df[col], unit='ms')
dogecoin_df = dogecoin_df.drop(columns=['Close', 'Close Time'])

# %%
# Function that will return new dataframe
def find_intervals(df_row, target_coin: DataFrame, interval: str = '5 minutes', plusminus='after'):
    td = pd.Timedelta(interval)
    timestamp = df_row['created_at']
    #  For current tweet (row) pull target coin data for specified interval before or after tweets timestamp
    if plusminus == 'after':
        coin_df = target_coin.where(target_coin['Open Time'].between(timestamp, timestamp+td)).dropna()
    elif plusminus == 'before':
        coin_df = target_coin.where(target_coin['Open Time'].between(timestamp, timestamp-td)).dropna()
    # Find values I want and populate columns for them
    try:
        dfmin = coin_df['Open'].iloc[0]
        dfmax = coin_df['Open'].iloc[-1]

        change = (dfmax - dfmin) / dfmin

        df_row[interval + ' beginning value'] = dfmin
        df_row[interval + ' end value'] = dfmax
        df_row[interval + ' change pct'] = change

        return df_row

    except Exception as e:
        return df_row.apply(lambda x: None)

# %%
# Defining the intervals I want for the 
intervals = ['5 minutes', '30 minutes']
intervals_plusminus = [('5 minutes', 'after'), ('30 minutes', 'after')]

# Loop will apply function to every row
crypto_btcval_tweets = crypto_tweets
crypto_dogeval_tweets = crypto_tweets
for interval, plusminus in intervals_plusminus:
    crypto_btcval_tweets = crypto_tweets.apply(find_intervals, axis=1, target_coin=bitcoin_df, interval=interval, plusminus=plusminus)
    crypto_dogeval_tweets = crypto_tweets.apply(find_intervals, axis=1, target_coin=dogecoin_df, interval=interval, plusminus=plusminus)
crypto_btcval_tweets
# crypto_btcval_tweets = crypto_btcval_tweets.dropna()
# crypto_dogeval_tweets = crypto_dogeval_tweets.dropna()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-5ac1aa5cfdb6> in <module>
#       8 for interval, plusminus in intervals_plusminus:
#       9     crypto_btcval_tweets = crypto_tweets.apply(find_intervals, axis=1, target_coin=bitcoin_df, interval=interval, plusminus=plusminus)
# ---> 10     crypto_dogeval_tweets = crypto_tweets.apply(find_intervals, axis=1, target_coin=dogecoin_df, interval=interval, plusminus=plusminus)
#      11 crypto_btcval_tweets
#      12 # crypto_btcval_tweets = crypto_btcval_tweets.dropna()
#
# NameError: name 'dogecoin_df' is not defined

# %%
crypto_btcval_tweets
# Out:
#       30 minutes beginning value  30 minutes change pct  30 minutes end value  \
# 4641                     7817.51               0.001117               7826.24
# 4193                     7816.16              -0.004866               7778.13
# 3608                     8796.60              -0.011126               8698.73
# 3606                     8764.71              -0.003761               8731.75
# 2770                     9152.91               0.000696               9159.28
# 1416                    23462.36              -0.001168              23434.96
# 1408                    23469.71               0.001425              23503.16
# 1407                    23436.67               0.002123              23486.42
# 1075                    37552.33               0.007927              37849.99
# 1072                    37835.23               0.000286              37846.04
# 1070                    37929.00              -0.001354              37877.63
# 1025                    38544.31              -0.007020              38273.73
# 1017                    38405.08               0.003684              38546.55
# 997                     46549.98               0.000098              46554.52
# 270  2021-05-20 13:13:36  1.395473e+18     1.0        1.0      0.0       0.0
# 254  2021-05-24 12:42:36  1.396915e+18     1.0        1.0      0.0       0.0
# 253  2021-05-24 12:49:56  1.396916e+18     0.0        1.0      1.0       0.0
# 252  2021-05-24 13:29:33  1.396926e+18     0.0        1.0      1.0       0.0
# 250  2021-05-24 22:37:12  1.397064e+18     0.0        1.0      1.0       0.0
# 249  2021-05-25 13:16:51  1.397286e+18     0.0        1.0      1.0       0.0
#
#                                            noun_phrases  polarity  \
# 4641                           ['bitcoin', 'safe word']  0.500000
# 4193                                           ['moon']  0.000000
# 3608                                        ['bitcoin']  0.000000
# 3606                             ['bitcoin', 'bitcoin']  0.200000
# 2770                  ['@ izzynobre', 'excuse', 'doge'] -0.025000
# 1416                           ['bitcoin', 'safe word']  0.500000
# 1408                          ['bitcoin', 'fiat money']  0.000000
# 1407                                           ['doge']  0.000000
# 1075                                           ['doge']  0.000000
# 1072                  ['dogecoin', 'people ’ s crypto']  0.000000
# 1070                                           ['doge']  0.000000
# 1025                                    ['who', 'doge']  0.000000
# 1017  ['@ itsallrisky', 'doge', 'unit time', 'btc', ... -0.125000
# 997            ['bought', 'dogecoin', 'toddler hodler']  0.000000
# 986                               ['@ gtera27', 'doge']  0.000000
# 975   ['dogecoin', 'full support', 'too', 'real issu...  0.218750
# 974   ['rationaletienne', 'acceptable percentage', '...  0.500000
# 956   ['@ business', 'tesla', '’ s action', 'bitcoin...  0.001389
# 955   ['@ business', 'don ’ t', 'stock besides', 'te...  0.085714
# 946                       ['peterschiff', 'btc', 'eth']  0.480000
# 944                              ['@ dogecoin', 'doge']  0.056250
# 933                                    ['dojo', 'doge']  0.000000
# 876           ['doge', 'meme shield', 'legendary item']  1.000000
# 870                        ['@ draecomino', 'dogecoin'] -0.375000
# 864                               ['wootieztv', 'doge']  0.260000
# 829                                    ['doge', 'egod']  0.000000
# 789                 ['btc', 'bitcoin', 'tbc', 'boring'] -1.000000
# 780                           ['doge', 'day afternoon']  0.000000
# 779   ['origin', 'doge', 'afternoon', 'dogecoin', 'd...  0.250000
# 761                           ['@ beeple 420m', 'doge']  0.000000
# 753                     ['@ lexfridman', '’ s', 'doge']  0.000000
# 709                                ['tesla', 'bitcoin']  0.000000
# 708   ['tesla', 'open source software', 'bitcoin', '...  0.025000
# 707                                  ['pay', 'bitcoin']  0.133333
# 648              ['spacex', 'dogecoin', 'literal moon']  0.000000
# 518        ['wsbchairman doge barking', 'moon', 'miro']  0.000000
# 517                            ['doge barking', 'moon']  0.000000
# 443   ['@ stoolpresidente', 'bitcoin', 'tesla', 'bit...  0.000000
# 352   ['spacex', 'doge-1', 'year – mission', 'doge',...  0.000000
# 342                                   ['tesla', 'doge']  0.000000
# 332                                ['tesla', 'bitcoin']  0.000000
# 326   ['working', 'doge', 'system transaction effici...  0.200000
# 319   ['@ itsallrisky', 'doge', 'block time 10x', 'i...  0.348148
# 317   ['@ long_elon @ itsallrisky', 'doge', '’ t', '...  0.000000
# 312                ['petermccormack obnoxious', 'doge']  0.000000
# 310   ['@ poisonouspinups @ michael_saylor', 'hallow...  0.160000
# 309   ['chainlinkgod', 'petermccormack bitcoin', 'co...  0.122143
# 305   ['btc_archive', 'clarify speculation', 'tesla'...  0.000000
# 286                                            ['doge']  0.200000
# 274   ['@ heydave7', 'tesla', 'doge', 'dollar sticke...  0.000000
# 273   ['@ heydave7', 'yeah', 'haven ’ t', '’ t', 'do...  0.000000
# 270   ['teslagong', '@ wintonark', 'bitcoin', 'energ... -0.229167
# 254   ['spoke', 'bitcoin', 'renewable usage', 'ww', ...  0.066667
# 253   ['’ d', 'doge', 'submit ideas', 'github', '//t...  0.000000
# 252      ['someone', 'dogecoin', 'pretty awesome haha']  0.483333
# 250              ['@ heydave7 @ dogecoin_devs', 'doge']  0.000000
# 249   ['@ itsallrisky', 'please', 'dogecoin', 'forma...  0.014286
#
#       subjectivity                                              tweet
# 4641      0.500000                      Bitcoin is *not* my safe word
# 4193      0.000000                                           Moon too
# 3608      0.000000                                        @Bitcoin 🤣🤣
# 3606      0.200000  @Bitcoin How much for some anime Bitcoin?  htt...
# 2770      0.525000            @izzynobre Excuse me, I only sell Doge!
# 1416      0.500000                            Bitcoin is my safe word
# 1408      0.000000              Bitcoin is almost as bs as fiat money
# 1407      0.000000                                     One word: Doge
# 1075      0.000000                                               Doge
# 1072      0.000000                    Dogecoin is the people’s crypto
# 1070      1.000000                       No highs, no lows, only Doge
# 1025      0.000000                           🎶 Who let the Doge out 🎶
# 1017      0.150000  @itsALLrisky Doge appears to be inflationary, ...
# 997       0.000000  Bought some Dogecoin for lil X, so he can be a...
# 986       0.000000                    @gtera27 Doge is underestimated
# 975       0.508333  If major Dogecoin holders sell most of their c...
# 974       0.500000  @RationalEtienne An acceptable percentage. Dog...
# 956       0.411111  @business Tesla’s action is not directly refle...
# 955       0.592857  @business To be clear, I am *not* an investor,...
# 946       0.620000  @PeterSchiff That said, BTC &amp; ETH do seem ...
# 944       0.350000  @dogecoin I just set up some little Doge minin...
# 933       0.000000                                        Dojo 4 Doge
# 876       1.000000  Doge meme shield (legendary item)  https://t.c...
# 870       0.500000                 @draecomino 2022: Dogecoin is dumb
# 864       0.260000  @WootiezTV Very much so &amp; its leader shall...
# 829       0.000000                     Doge spelled backwards is Egod
# 789       1.000000  BTC (Bitcoin) is an anagram of TBC(The Boring ...
# 780       0.000000                                 Doge day afternoon
# 779       0.850000  Origin of Doge Day Afternoon: The ancient Roma...
# 761       0.000000                                  @beeple 420M Doge
# 753       0.000000              @lexfridman Sometimes it’s about Doge
# 709       0.000000               You can now buy a Tesla with Bitcoin
# 708       0.475000  Tesla is using only internal &amp; open source...
# 707       0.150000  Pay by Bitcoin capability available outside US...
# 648       0.000000  SpaceX is going to put a literal Dogecoin on t...
# 518       0.000000  @WSBChairman Doge Barking at the Moon – Miro  ...
# 517       0.000000  Doge Barking at the Moon  https://t.co/QFB81D7zOL
# 443       0.300000  @stoolpresidente No, you do not. I have not so...
# 352       0.000000  SpaceX launching satellite Doge-1 to the moon ...
# 342       0.000000                  Do you want Tesla to accept Doge?
# 332       0.000000       Tesla &amp; Bitcoin  https://t.co/YSswJmVZhP
# 326       0.500000  Working with Doge devs to improve system trans...
# 319       0.496296  @itsALLrisky Ideally, Doge speeds up block tim...
# 317       0.550000  @long_elon @itsALLrisky Only if Doge can’t do ...
# 312       0.000000  @PeterMcCormack Obnoxious threads like this ma...
# 310       0.540000  @poisonouspinups @michael_saylor He should wea...
# 309       0.313571  @ChainLinkGod @PeterMcCormack Bitcoin is actua...
# 305       0.000000  @BTC_Archive To clarify speculation, Tesla has...
# 286       0.200000  How much is that Doge in the window?  https://...
# 274       0.000000  @heydave7 A longtime Tesla supporter gave me t...
# 273       0.000000  @heydave7 Yeah, I haven’t &amp; won’t sell any...
# 270       0.625000  @TeslaGong @wintonARK Bitcoin hashing (aka min...
# 254       0.300000  Spoke with North American Bitcoin miners. They...
# 253       0.000000  If you’d like to help develop Doge, please sub...
# 252       0.766667  Someone suggested changing Dogecoin fees based...
# 250       0.000000  @heydave7 @dogecoin_devs Doge has dogs &amp; m...
# 249       0.121429  @itsALLrisky Please note Dogecoin has no forma...

# %%
# Not sure why columns got messed up, but fixing it here
crypto_btcval_tweets = crypto_btcval_tweets[['id', 'created_at', 'tweet', 'noun_phrases', 'polarity', 'subjectivity', 'is_btc', 'is_doge', 'is_crypto', 'is_tesla', '5 minutes beginning value', '5 minutes end value', '5 minutes change pct', '30 minutes beginning value', '30 minutes end value', '30 minutes change pct']]
crypto_dogeval_tweets = crypto_dogeval_tweets[['id', 'created_at', 'tweet', 'noun_phrases', 'polarity', 'subjectivity', 'is_btc', 'is_doge', 'is_crypto', 'is_tesla', '5 minutes beginning value', '5 minutes end value', '5 minutes change pct', '30 minutes beginning value', '30 minutes end value', '30 minutes change pct']]

crypto_btcval_tweets.to_csv('crypto_tweets.csv', index=False)
crypto_dogeval_tweets.to_csv('crypto_tweets.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-12-3ed609f4be65> in <module>
#       1 # Not sure why columns got messed up, but fixing it here
# ----> 2 crypto_btcval_tweets = crypto_btcval_tweets[['id', 'created_at', 'tweet', 'noun_phrases', 'polarity', 'subjectivity', 'is_btc', 'is_doge', 'is_crypto', 'is_tesla', '5 minutes beginning value', '5 minutes end value', '5 minutes change pct', '30 minutes beginning value', '30 minutes end value', '30 minutes change pct']]
#       3 crypto_dogeval_tweets = crypto_dogeval_tweets[['id', 'created_at', 'tweet', 'noun_phrases', 'polarity', 'subjectivity', 'is_btc', 'is_doge', 'is_crypto', 'is_tesla', '5 minutes beginning value', '5 minutes end value', '5 minutes change pct', '30 minutes beginning value', '30 minutes end value', '30 minutes change pct']]
#       4
#       5 crypto_btcval_tweets.to_csv('crypto_tweets.csv', index=False)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3459             if is_iterator(key):
#    3460                 key = list(key)
# -> 3461             indexer = self.loc._get_listlike_indexer(key, axis=1)[1]
#    3462
#    3463         # take() does not accept boolean indexers
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis)
#    1312             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1313
# -> 1314         self._validate_read_indexer(keyarr, indexer, axis)
#    1315
#    1316         if needs_i8_conversion(ax.dtype) or isinstance(
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _validate_read_indexer(self, key, indexer, axis)
#    1375
#    1376             not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 1377             raise KeyError(f"{not_found} not in index")
#    1378
#    1379
#
# KeyError: "['5 minutes beginning value', '5 minutes end value', '5 minutes change pct'] not in index"
